# %%
from highlight import highlight_vis, vis_dict
from IPython.display import HTML
# Out:
# Loading from /Users/lschueller/Documents/MA/ma-leon-schueller---abstractive-summarization/data/models/model_XXXVIII_e20.pt
# =======================Config================================
# B | 3
# N | 3
# attention_type | Luong
# batch_size | 12
# beta_1 | 0.9
# beta_2 | 0.999
# bias | True
# bp | None
# criterion | torch.nn.NLLLoss()
# d | 0
# d_ff | 1024
# d_model | 256
# dataset | CnnDm
# dec_max_len | 500
# decoder | Recurrent
# device | cpu
# dropout | 0.1
# dump | False
# emb_dim | 300
# emb_name | data/embeddings/wiki.en.vec
# enc_max_len | 2300
# encoder | Recurrent
# eps | 1e-9
# eval_beam | True
# factor | 1
# from_epoch | 20
# from_save_description | XXXVIII
# h | 4
# hidden_dim | 256
# init | True
# k | 1.2
# lambda_ | 0.999
# loader_num_workers | 1
# log_interval | 2
# max_vocab | 50000
# norm | True
# num_epochs | 21
# num_layers | 1
# num_threads | 1
# opt_eps | 1e-8
# pin_memory | False
# pointer | True
# resume | True
# rl | False
# rnn_type | LSTM
# save_description | XXXVIII
# save_dir | data/models
# save_interval | 4
# shuffle | True
# ss | 380
# tf_prob | 1
# tied_weights | True
# toy_run | False
# trainable | True
# val_interval | None
# vocab_path | /Users/lschueller/Documents/MA/ma-leon-schueller---abstractive-summarization/data/cnn_dm_finished_files/vocab
# w_type | dynamic
# warmup | 4000
# weight_decay | 1e-05
# windowing | True
# ws | 400
# =============================================================
# Loading from /Users/lschueller/Documents/MA/ma-leon-schueller---abstractive-summarization/data/models/model_XXXVIII_e20.pt

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
test=vis_dict()
HTML(highlight_vis(test, snapshot=True, hue=270))
# Out:
#     <!DOCTYPE html>
#     <html lang="en">
#     <head>
#     <meta charset="utf-8">
#     <title>Model Attention Visualization</title>
#     <style type="text/css">
#         .Header {
#           color: hsl(270, 20%, 20%);
#           font-weight: bold;
#           font-style: italic;
#         }
#         .HeadWrapper {
#           border-style: solid;
#           border-color: hsl(270, 20%, 20%);
#           padding: 5px;
#         }
#     </style>
#     </head>
#     <body>
#         <div class="HeadWrapper"><div class="Header"> ARTICLE: </div><div class="Articles"><span style="background-color: hsl(270, 100%, 100%)">Hong</span> <span style="background-color: hsl(270, 100%, 100%)">Kong</span> <span style="background-color: hsl(270, 100%, 100%)">Protest</span> <span style="background-color: hsl(270, 100%, 100%)">Updates</span> <span style="background-color: hsl(270, 100%, 100%)">:</span> <span style="background-color: hsl(270, 100%, 94%)">Standoff</span> <span style="background-color: hsl(270, 100%, 94%)">With</span> <span style="background-color: hsl(270, 100%, 100%)">Police</span> <span style="background-color: hsl(270, 100%, 100%)">After</span> <span style="background-color: hsl(270, 100%, 100%)">Clashes</span> <span style="background-color: hsl(270, 100%, 100%)">Demonstrators</span> <span style="background-color: hsl(270, 100%, 100%)">,</span> <span style="background-color: hsl(270, 100%, 100%)">protesting</span> <span style="background-color: hsl(270, 100%, 100%)">a</span> <span style="background-color: hsl(270, 100%, 100%)">contentious</span> <span style="background-color: hsl(270, 100%, 100%)">extradition</span> <span style="background-color: hsl(270, 100%, 100%)">bill</span> <span style="background-color: hsl(270, 100%, 100%)">,</span> <span style="background-color: hsl(270, 100%, 100%)">threw</span> <span style="background-color: hsl(270, 100%, 100%)">bricks</span> <span style="background-color: hsl(270, 100%, 100%)">,</span> <span style="background-color: hsl(270, 100%, 100%)">bottles</span> <span style="background-color: hsl(270, 100%, 100%)">and</span> <span style="background-color: hsl(270, 100%, 100%)">umbrellas</span> <span style="background-color: hsl(270, 100%, 100%)">at</span> <span style="background-color: hsl(270, 100%, 100%)">riot</span> <span style="background-color: hsl(270, 100%, 100%)">police</span> <span style="background-color: hsl(270, 100%, 100%)">guarding</span> <span style="background-color: hsl(270, 100%, 100%)">the</span> <span style="background-color: hsl(270, 100%, 100%)">city</span> <span style="background-color: hsl(270, 100%, 100%)">'s</span> <span style="background-color: hsl(270, 100%, 100%)">Legislative</span> <span style="background-color: hsl(270, 100%, 100%)">Council</span> <span style="background-color: hsl(270, 100%, 100%)">.</span> <span style="background-color: hsl(270, 100%, 100%)">The</span> <span style="background-color: hsl(270, 100%, 100%)">police</span> <span style="background-color: hsl(270, 100%, 100%)">responded</span> <span style="background-color: hsl(270, 100%, 100%)">with</span> <span style="background-color: hsl(270, 100%, 100%)">tear</span> <span style="background-color: hsl(270, 100%, 100%)">gas</span> <span style="background-color: hsl(270, 100%, 100%)">,</span> <span style="background-color: hsl(270, 100%, 100%)">pepper</span> <span style="background-color: hsl(270, 100%, 100%)">spray</span> <span style="background-color: hsl(270, 100%, 100%)">and</span> <span style="background-color: hsl(270, 100%, 100%)">rubber</span> <span style="background-color: hsl(270, 100%, 100%)">bullets</span> <span style="background-color: hsl(270, 100%, 100%)">.</span> <span style="background-color: hsl(270, 100%, 100%)">By</span> <span style="background-color: hsl(270, 100%, 100%)">The</span> <span style="background-color: hsl(270, 100%, 94%)">New</span> <span style="background-color: hsl(270, 100%, 100%)">York</span> <span style="background-color: hsl(270, 100%, 100%)">Times</span> <span style="background-color: hsl(270, 100%, 100%)">RIGHT</span> <span style="background-color: hsl(270, 100%, 92%)">NOW</span> <span style="background-color: hsl(270, 100%, 94%)">``</span> <span style="background-color: hsl(270, 100%, 76%)">I</span> <span style="background-color: hsl(270, 100%, 76%)">have</span> <span style="background-color: hsl(270, 100%, 72%)">never</span> <span style="background-color: hsl(270, 100%, 79%)">felt</span> <span style="background-color: hsl(2 ...
